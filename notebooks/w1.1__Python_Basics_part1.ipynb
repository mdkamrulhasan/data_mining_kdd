# %% [markdown]
# # CIS 635 — Knowledge Discovery & Data Mining
# ## Python Basics: Interactive Colab Notebook
#
# ### Introduction
#
# This notebook provides an interactive companion to the **Python Basics** portion of the CIS 635 course material. It focuses on the foundational Python concepts used throughout the course and connects them to simple data-oriented and real-world examples.
#
# ### Learning objectives
#
# By completing this notebook, you should be able to:
#
# - Create and use variables with common Python data types.
# - Use arithmetic, comparison, logical, and assignment operators.
# - Write conditional statements using `if`, `elif`, and `else`.
# - Use `for` and `while` loops.
# - Create and call functions with parameters, return values, and default arguments.
# - Work with lists, tuples, dictionaries, and sets.
# - Use list comprehensions for simple data-selection and transformation tasks.
# - Apply these concepts to small examples related to data analysis and knowledge discovery.
#
# > **How to use this notebook:** Read each explanation, run each code cell, modify the examples, and complete the exercises. Every code cell is preceded by a short comment describing its purpose.

# %% [markdown]
# ## 1. Variables and Basic Data Types

# %% [markdown]
# **Code cell purpose:** Create variables representing a simple patient record and inspect their Python data types.

# %%
# Variables can store different kinds of values.
patient_id = "P-10432"          # str
age = 47                        # int
body_temp_c = 38.6              # float
is_fever = body_temp_c > 37.5   # bool
allergy_notes = None            # NoneType: no value recorded

print(patient_id, type(patient_id))
print(age, type(age))
print(body_temp_c, type(body_temp_c))
print(is_fever, type(is_fever))
print(allergy_notes, type(allergy_notes))

# %% [markdown]
# ### Key idea
# Python is dynamically typed. Common types used throughout this course include:
#
# - `int`: whole numbers
# - `float`: decimal numbers
# - `str`: text
# - `bool`: `True` or `False`
# - `None`: the deliberate absence of a value
#
# In data analysis, `None` should not automatically be treated as `0`, `False`, or an empty string.

# %% [markdown]
# ## 2. Arithmetic Operators

# %% [markdown]
# **Code cell purpose:** Compute a simple healthcare bill using addition, subtraction, multiplication, and division, then demonstrate floor division, modulo, and exponentiation.

# %%
visit_fee = 120.00
lab_fee = 45.50
discount_pct = 10

subtotal = visit_fee + lab_fee
discount_amount = subtotal * discount_pct / 100
total_due = subtotal - discount_amount

print("Subtotal:", subtotal)
print("Discount amount:", discount_amount)
print("Total due:", total_due)

print("\nFloor division 47 // 10 =", 47 // 10)
print("Modulo 47 % 10 =", 47 % 10)
print("Exponent 2 ** 5 =", 2 ** 5)

# %% [markdown]
# ## 3. Comparison, Logical, and Assignment Operators

# %% [markdown]
# **Code cell purpose:** Use comparisons and logical operators to determine whether a patient should be considered high risk or worth flagging for review.

# %%
temperature_threshold = 37.5
age_threshold = 65

is_high_risk = (body_temp_c > temperature_threshold) and (age >= age_threshold)
is_worth_flagging = (body_temp_c > temperature_threshold) or (age >= age_threshold)

print("High risk:", is_high_risk)
print("Worth flagging:", is_worth_flagging)
print("Not fever:", not is_fever)
print("Age is not 47:", age != 47)

running_total = 0
running_total += subtotal
print("Running total after += subtotal:", running_total)

# %% [markdown]
# ### Common pitfall
# Use `=` for assignment and `==` for comparison.
#
# - `age = 65` assigns a value.
# - `age == 65` checks whether two values are equal.

# %% [markdown]
# ## 4. Conditional Statements

# %% [markdown]
# **Code cell purpose:** Define a reusable function that converts a numerical score into a letter grade using an `if`/`elif`/`else` chain.

# %%
def letter_grade(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    elif score >= 60:
        return "D"
    else:
        return "F"

for score in [95, 82, 71, 58]:
    print(f"Score {score} -> Grade {letter_grade(score)}")

# %% [markdown]
# ## 5. `for` Loops

# %% [markdown]
# **Code cell purpose:** Process a list of scores one item at a time and display the corresponding letter grade.

# %%
scores = [95, 82, 71, 58, 88, 64, 90]

for score in scores:
    print(f"{score} -> {letter_grade(score)}")

# %% [markdown]
# **Code cell purpose:** Use `enumerate()` to access both the position and value of each item while processing a sequence.

# %%
for i, score in enumerate(scores, start=1):
    print(f"Student #{i}: score {score}")

# %% [markdown]
# ## 6. `while` Loops

# %% [markdown]
# **Code cell purpose:** Simulate sensor monitoring until three consecutive readings fall within a safe range or a maximum number of attempts is reached.

# %%
# Predetermined readings make the example reproducible in Colab.
sensor_values = [45.2, 56.0, 92.4, 46.6, 50.8, 58.7]

consecutive_stable = 0
attempts = 0
readings = []

while consecutive_stable < 3 and attempts < len(sensor_values):
    value = sensor_values[attempts]
    readings.append(value)
    attempts += 1

    if 30.0 <= value <= 70.0:
        consecutive_stable += 1
    else:
        consecutive_stable = 0

print("Readings taken:", readings)
print("Attempts used:", attempts)
print("Stopped after 3 consecutive stable readings:", consecutive_stable == 3)

# %% [markdown]
# ## 7. List Comprehensions

# %% [markdown]
# **Code cell purpose:** Use list comprehensions to transform scores, select passing scores, and apply a simple score adjustment.

# %%
grades = [letter_grade(s) for s in scores]
passing_scores = [s for s in scores if s >= 60]
curved_passing = [s + 5 for s in scores if s >= 60]

print("Grades:", grades)
print("Passing scores:", passing_scores)
print("Curved passing scores:", curved_passing)

# %% [markdown]
# A common pattern is:
#
# ```python
# [expression for item in sequence if condition]
# ```
#
# This pattern is useful in KDD for selection, preprocessing, and transformation.

# %% [markdown]
# ## 8. Functions

# %% [markdown]
# **Code cell purpose:** Define and call a simple function with one parameter and a return value.

# %%
def celsius_to_fahrenheit(temp_c):
    """Convert a Celsius temperature to Fahrenheit."""
    return temp_c * 9 / 5 + 32

for temp_c in [0, 20, 37, 100]:
    print(f"{temp_c} C -> {celsius_to_fahrenheit(temp_c)} F")

# %% [markdown]
# ## 9. Parameters, Default Arguments, and Return Values

# %% [markdown]
# **Code cell purpose:** Define a function with multiple parameters and a default argument to calculate a fixed loan payment.

# %%
def loan_monthly_payment(principal, annual_rate_pct, years, periods_per_year=12):
    """Compute a fixed payment for a standard amortizing loan."""
    n_periods = years * periods_per_year
    rate_per_period = (annual_rate_pct / 100) / periods_per_year

    if rate_per_period == 0:
        return principal / n_periods

    payment = principal * (
        rate_per_period * (1 + rate_per_period) ** n_periods
    ) / ((1 + rate_per_period) ** n_periods - 1)

    return payment

print("Monthly payment:", round(loan_monthly_payment(20000, 6.0, 5), 2))
print("Quarterly payment:", round(
    loan_monthly_payment(20000, 6.0, 5, periods_per_year=4), 2
))

# %% [markdown]
# ## 10. Returning Multiple Values

# %% [markdown]
# **Code cell purpose:** Calculate the minimum, maximum, and mean of a list using only basic Python and return all three values from one function.

# %%
def summarize(values):
    """Return the minimum, maximum, and mean of a list of numbers."""
    total = 0
    lowest = values[0]
    highest = values[0]

    for v in values:
        total += v
        if v < lowest:
            lowest = v
        if v > highest:
            highest = v

    mean = total / len(values)
    return lowest, highest, mean

class_sizes = [22, 31, 18, 27, 25, 40, 19]
low, high, mean = summarize(class_sizes)

print("Minimum:", low)
print("Maximum:", high)
print("Mean:", round(mean, 2))

# %% [markdown]
# ## 11. Function Composition

# %% [markdown]
# **Code cell purpose:** Reuse the previously defined `summarize()` function inside another function to identify oversized classes.

# %%
def flag_oversized_classes(class_sizes, cap=30):
    _, largest, _ = summarize(class_sizes)
    oversized = [size for size in class_sizes if size > cap]
    over_by = largest - cap if largest > cap else 0
    return oversized, over_by

oversized, over_by = flag_oversized_classes(class_sizes, cap=30)
print("Oversized classes:", oversized)
print("Largest class exceeds the cap by:", over_by)

# %% [markdown]
# ## 12. Lists

# %% [markdown]
# **Code cell purpose:** Demonstrate indexing, negative indexing, slicing, appending, measuring length, and sorting with a list of daily sales values.

# %%
daily_sales = [412.50, 389.00, 455.75, 402.10, 610.25, 720.00, 388.90]

print("First day:", daily_sales[0])
print("Last day:", daily_sales[-1])
print("Friday-Saturday:", daily_sales[4:6])

daily_sales.append(399.40)
print("After append:", daily_sales)
print("Length:", len(daily_sales))
print("Sorted:", sorted(daily_sales))

# %% [markdown]
# ## 13. Tuples

# %% [markdown]
# **Code cell purpose:** Create an immutable coordinate pair and unpack its values into separate variables.

# %%
station_location = (39.1031, -84.5120)
lat, lon = station_location

print("Station location:", station_location)
print("Latitude:", lat)
print("Longitude:", lon)

# %% [markdown]
# ## 14. Dictionaries

# %% [markdown]
# **Code cell purpose:** Represent a patient as a key-value record, update an existing value, add a new field, and safely retrieve a potentially missing field.

# %%
patient_record = {
    "patient_id": "P-10432",
    "age": 47,
    "diagnosis_code": "J45.909",
    "visits_this_year": 3,
}

patient_record["visits_this_year"] += 1
patient_record["last_visit_flagged"] = True

print("Patient age:", patient_record["age"])
print("Visits this year:", patient_record["visits_this_year"])
print("Allergy:", patient_record.get("allergy", "not recorded"))
print("Keys:", list(patient_record.keys()))

# %% [markdown]
# ## 15. Sets

# %% [markdown]
# **Code cell purpose:** Compare two sets of topics using intersection, difference, and symmetric difference.

# %%
section_a_topics = {"loops", "functions", "lists", "dictionaries"}
section_b_topics = {"functions", "dictionaries", "sets", "recursion"}

print("Both sections:", section_a_topics & section_b_topics)
print("A only:", section_a_topics - section_b_topics)
print("Exactly one section:", section_a_topics ^ section_b_topics)

# %% [markdown]
# **Code cell purpose:** Use a set to remove duplicate field identifiers and then sort the result for reproducible output.

# %%
raw_field_ids = ["A1", "A2", "A3", "A1", "B1", "A2", "B1", "C1"]
unique_field_ids = set(raw_field_ids)

print("Original count:", len(raw_field_ids))
print("Unique count:", len(unique_field_ids))
print("Duplicates removed:", len(raw_field_ids) - len(unique_field_ids))
print("Sorted unique IDs:", sorted(unique_field_ids))

# %% [markdown]
# # Practical Exercises
#
# Complete the following exercises without looking at the solutions first. Add new code cells below each exercise or create your own cells at the end of the notebook.

# %% [markdown]
# ## Exercise 1: Variables and Boolean Logic
#
# Create three variables representing a retail transaction:
# - `item_price` as a float
# - `quantity` as an integer
# - `is_member_discount_applied` as a Boolean
#
# Compute the final total, applying a 5% discount only when the Boolean is `True`.

# %% [markdown]
# **Code cell purpose:** Use this blank workspace to write and test your solution.

# %%
# Write your solution here.

# %% [markdown]
# ## Exercise 2: Division Operators
#
# Evaluate `7 / 2` and `7 // 2`. Explain the difference. Then provide one realistic example where floor division would be useful.

# %% [markdown]
# **Code cell purpose:** Use this blank workspace to write and test your solution.

# %%
# Write your solution here.

# %% [markdown]
# ## Exercise 3: Missing Values
#
# A patient age field uses `0` whenever the age is missing instead of `None`. In 2–3 sentences, explain how this could distort an average-age calculation during data preprocessing.

# %% [markdown]
# **Code cell purpose:** Use this blank workspace to write and test your solution.

# %%
# Write your solution here.

# %% [markdown]
# ## Exercise 4: Conditional Statements
#
# Write `risk_category(days_since_last_login)` that returns:
# - `"low"` for 0–3 days
# - `"medium"` for 4–10 days
# - `"high"` for more than 10 days
#
# Test at least five values, including the boundary value 10.

# %% [markdown]
# **Code cell purpose:** Use this blank workspace to write and test your solution.

# %%
# Write your solution here.

# %% [markdown]
# ## Exercise 5: Grade Counting
#
# Using a `for` loop, count how many scores fall into each letter grade. Store the results in a dictionary. Do not use a list comprehension for this exercise.

# %% [markdown]
# **Code cell purpose:** Use this blank workspace to write and test your solution.

# %%
# Write your solution here.

# %% [markdown]
# ## Exercise 6: List Comprehension
#
# Convert this logic into a list comprehension:
#
# ```python
# result = []
# for x in readings:
#     if x > 50:
#         result.append(x * 2)
# ```
#
# Then briefly explain whether the list-comprehension version is more readable.

# %% [markdown]
# **Code cell purpose:** Use this blank workspace to write and test your solution.

# %%
# Write your solution here.

# %% [markdown]
# ## Exercise 7: Functions
#
# Write `fahrenheit_to_celsius(temp_f)` and verify that converting 37°C to Fahrenheit and back returns approximately 37°C. Test at least three temperatures.

# %% [markdown]
# **Code cell purpose:** Use this blank workspace to write and test your solution.

# %%
# Write your solution here.

# %% [markdown]
# ## Exercise 8: Data Structures
#
# Given:
#
# ```python
# weekly_temps = [68, 71, 74, 69, 72, 77, 75]
# ```
#
# Use indexing and slicing to extract the first three days, the last two days, and the highest temperature without using `sorted()`.

# %% [markdown]
# **Code cell purpose:** Use this blank workspace to write and test your solution.

# %%
# Write your solution here.

# %% [markdown]
# ## Exercise 9: Dictionary Accumulator
#
# Given at least ten exam scores, use a dictionary to count the number of A, B, C, D, and F grades.

# %% [markdown]
# **Code cell purpose:** Use this blank workspace to write and test your solution.

# %%
# Write your solution here.

# %% [markdown]
# ## Exercise 10: Set Operations
#
# Two hospital wards store diagnosis codes in sets. Write code to find:
# 1. Codes seen at either ward
# 2. Codes seen at both wards
# 3. Codes seen at the first ward but not the second
#
# Briefly explain what each result could be useful for.

# %% [markdown]
# **Code cell purpose:** Use this blank workspace to write and test your solution.

# %%
# Write your solution here.

# %% [markdown]
# # Self-Check Challenge
#
# Before moving to the next topic, make sure you can independently:
#
# - Explain the difference between `None` and `0`.
# - Use `=` and `==` correctly.
# - Write an `if`/`elif`/`else` chain.
# - Choose between a `for` loop and a `while` loop.
# - Write a basic function with parameters and a return value.
# - Explain when to use a list, tuple, dictionary, or set.
# - Write and read a basic list comprehension.
# - Process a small collection of records using plain Python.
#
# If you cannot yet complete one of these tasks, revisit the corresponding section, modify the examples, and run additional tests before continuing.

# %% [markdown]
# ## Optional Extension: A Small Data-Oriented Challenge
#
# Create a small list of dictionaries representing sensor readings. Each record should contain a field ID, a temperature, and a moisture value. Then:
#
# 1. Remove records with missing moisture values.
# 2. Flag readings outside a reasonable range.
# 3. Create a list of field IDs that pass your validity checks.
# 4. Use a function to categorize valid moisture readings as `"dry"`, `"normal"`, or `"moist"`.
#
# This optional activity combines variables, dictionaries, conditionals, loops, functions, and list comprehensions in a workflow similar to early KDD preprocessing tasks.
